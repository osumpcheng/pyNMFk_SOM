# %%
import pandas as pd
import numpy as np

df_env = pd.read_csv('/home/shic892/corems/1000s_env_w_biome_meta_v4.csv',index_col = 0,encoding='latin-1')
df_env.columns
# Out:
# Index(['mean_GWC', 'K_mg_per_kg', 'SO4.S_mg_per_kg', 'B_mg_per_kg',
#        'Zn_mg_per_kg', 'Mn_mg_per_kg', 'Cu_mg_per_kg', 'Fe_mg_per_kg',
#        'Ca_Meq_per_100_g', 'Mg_Meq_per_100_g', 'Na_Meq_per_100_g',
#        'Total_Bases_Meq_per_100_g', 'CEC_Meq_per_100_g', 'TKN_pct',
#        'Total_Sulfur_pct', 'Total_Nitrogen_pct', 'Total_Carbon_pct',
#        'C_to_N_ratio', 'NO3.N_mg_per_g_of_soil_mean',
#        'NH4.N_mg_per_g_of_soil_mean', 'P_Bicarb_mg_per_g_of_soil_mean', 'pH',
#        'B.glucosidase_ug_pNP_per_g_per_hour',
#        'Respiration_96_h_ug_CO2.C_per_g_soil_per_day',
#        'Respiration_24_h_ug_CO2.C_per_g_soil_per_day', 'Sand_pct', 'Silt_pct',
#        'Clay_pct', 'name', 'longitude', 'latitude', 'OBJECTID', 'AREA',
#        'PERIMETER', 'ECO_NAME', 'REALM', 'BIOME', 'ECO_NUM', 'ECO_ID',
#        'ECO_SYM', 'GBL_STAT', 'G200_REGIO', 'G200_NUM', 'G200_BIOME',
#        'G200_STAT', 'Shape_Leng', 'Shape_Area', 'area_km2', 'eco_code',
# ...

# %%
df_env.iloc[:,56:61]
# Out:
#                 Lat        Long  Elev.m  Soil.Temperature.C  \
# Sample
# ANZA_BTM  33.305325 -116.254011   191.0                42.7
# ANZA_TOP  33.305325 -116.254011   191.0                42.7
# BLAN_BTM  39.059410  -78.072070   174.0                19.7
# BLAN_TOP  39.059410  -78.072070   174.0                19.7
# CFS1_BTM  35.382800  -78.038180    24.0                18.5
# ...             ...         ...     ...                 ...
# WY09_TOP  43.583143 -109.946757  2802.0                22.5
# WY10_BTM  43.582587 -109.971750  2865.0                13.4
# WY10_TOP  43.582587 -109.971750  2865.0                13.4
# WY15_BTM  42.581893 -108.751004  2639.0                23.0
# WY15_TOP  42.581893 -108.751004  2639.0                23.0
#
#           VolWaterContent.m3.m3
# Sample
# ANZA_BTM                 0.0490
# ANZA_TOP                 0.0490
# BLAN_BTM                 0.1740
# BLAN_TOP                 0.1740
# CFS1_BTM                 0.0515
# ...

# %%
df_env_short = df_env.iloc[:,np.append(range(0,28), range(56,61))]
df_env_short.columns
# Out:
# Index(['mean_GWC', 'K_mg_per_kg', 'SO4.S_mg_per_kg', 'B_mg_per_kg',
#        'Zn_mg_per_kg', 'Mn_mg_per_kg', 'Cu_mg_per_kg', 'Fe_mg_per_kg',
#        'Ca_Meq_per_100_g', 'Mg_Meq_per_100_g', 'Na_Meq_per_100_g',
#        'Total_Bases_Meq_per_100_g', 'CEC_Meq_per_100_g', 'TKN_pct',
#        'Total_Sulfur_pct', 'Total_Nitrogen_pct', 'Total_Carbon_pct',
#        'C_to_N_ratio', 'NO3.N_mg_per_g_of_soil_mean',
#        'NH4.N_mg_per_g_of_soil_mean', 'P_Bicarb_mg_per_g_of_soil_mean', 'pH',
#        'B.glucosidase_ug_pNP_per_g_per_hour',
#        'Respiration_96_h_ug_CO2.C_per_g_soil_per_day',
#        'Respiration_24_h_ug_CO2.C_per_g_soil_per_day', 'Sand_pct', 'Silt_pct',
#        'Clay_pct', 'Lat', 'Long', 'Elev.m', 'Soil.Temperature.C',
#        'VolWaterContent.m3.m3'],
#       dtype='object')

# %%
df_env_short = df_env_short.drop(['TKN_pct'], axis=1)

# %%
df_env_short.corr().loc['Respiration_24_h_ug_CO2.C_per_g_soil_per_day']
# Out:
# mean_GWC                                        0.419005
# K_mg_per_kg                                     0.154543
# SO4.S_mg_per_kg                                 0.184134
# B_mg_per_kg                                     0.303562
# Zn_mg_per_kg                                    0.291911
# Mn_mg_per_kg                                    0.472418
# Cu_mg_per_kg                                    0.172116
# Fe_mg_per_kg                                    0.232407
# Ca_Meq_per_100_g                                0.389774
# Mg_Meq_per_100_g                                0.341698
# Na_Meq_per_100_g                                0.053905
# Total_Bases_Meq_per_100_g                       0.388801
# CEC_Meq_per_100_g                               0.490390
# Total_Sulfur_pct                                0.315687
# Total_Nitrogen_pct                              0.617187
# Total_Carbon_pct                                0.566851
# ...

# %%
import matplotlib.pyplot as plt

df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='Mn_mg_per_kg', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='Mn_mg_per_kg'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='mean_GWC', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='mean_GWC'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='TKN_pct',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='TKN_pct'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='Total_Carbon_pct',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='Total_Carbon_pct'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='Total_Sulfur_pct',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='Total_Sulfur_pct'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='pH',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='pH'>

# %%
df_env.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='Soil.Temperature.C',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', ylabel='Soil.Temperature.C'>

# %%
#df_env_log = np.log10(df_env_short.iloc[:,:-1]+1)
df_env_short.plot.scatter(x='Respiration_24_h_ug_CO2.C_per_g_soil_per_day', y='Total_Sulfur_pct', c='DarkBlue',logx=True, logy=True,
                          xlabel='respiration_24hr_CO2 (ug/g soil/day)', ylabel='Total sulfur (%)')
# Out:
# <AxesSubplot:xlabel='respiration_24hr_CO2 (ug/g soil/day)', ylabel='Total sulfur (%)'>

# %%
df_env_short['Respiration_24_h_ug_CO2.C_per_g_soil_per_day'] = np.log10(df_env_short['Respiration_24_h_ug_CO2.C_per_g_soil_per_day']+1)
df_env_short['Total_Carbon_pct'] = np.log10(df_env_short['Total_Carbon_pct']+1)
df_env_short['Total_Nitrogen_pct'] = np.log10(df_env_short['Total_Nitrogen_pct']+1)
df_env_short['Total_Sulfur_pct'] = np.log10(df_env_short['Total_Sulfur_pct']+1)
df_env_short['Mn_mg_per_kg']= np.log10(df_env_short['Mn_mg_per_kg']+1)

# %%
df_env_short['C_to_N_ratio']= np.log10(df_env_short['C_to_N_ratio']+1)

# %%
df_env_short['Total_Bases_Meq_per_100_g']= df_env['Total_Bases_Meq_per_100_g']
df_env_short['Total_Sulfur_pct']= df_env['Total_Sulfur_pct']

# %%
df_env_short['Depth'] = [x[5:8] for x in df_env_short.index.values]

# %%
df_env_short.loc[df_env_short['Depth']=='TOP', 'Depth'] = 'Surface'
df_env_short.loc[df_env_short['Depth']=='BTM', 'Depth'] = 'Subsoil'

# %%
df_env_short['Total_Bases_Meq_per_100_g'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
#from scipy import stats
        
#slope, intercept, r_value, pv, se = stats.linregress(df['alcohol'],df['magnesium'])

g = sns.lmplot(x="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", y="Total_Carbon_pct", data=df_env_short,)
                  #kind="reg", truncate=False,
                  #xlim=(0, 60), ylim=(0, 12),
                  #logx=True,ci=90,
                  #color="m", height=6,)
                  #label="y={0:.1f}x+{1:.1f}".format(slope, intercept))
#g.legend(loc="best")
g.axes[0,0].set_xlabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_ylabel('Total Carbon (log%)')
#g.ax_joint.set_yscale('log')
# Out:
# Text(36.265625, 0.5, 'Total Carbon (log%)')

# %%
g = sns.lmplot(x="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", y="Total_Nitrogen_pct", data=df_env_short,)
g.axes[0,0].set_xlabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_ylabel('Total Nitrogen (log%)')
# Out:
# Text(26.640625, 0.5, 'Total Nitrogen (log%)')

# %%
g = sns.lmplot(y="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", x="C_to_N_ratio", data=df_env_short,hue='depth')
g.axes[0,0].set_ylabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_xlabel('C_to_N_ratio')
# Out:
# Text(0.5, 29.140624999999986, 'C_to_N_ratio')

# %%
g = sns.lmplot(x="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", y="Mn_mg_per_kg", data=df_env_short,)
g.axes[0,0].set_xlabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_ylabel('Mn (log mg/kg)')
# Out:
# Text(26.765625, 0.5, 'Mn (log mg/kg)')

# %%
g = sns.lmplot(x="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", y="Soil.Temperature.C", data=df_env_short,)
g.axes[0,0].set_xlabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_ylabel('Soil Temperature (degree C)')
# Out:
# Text(40.875, 0.5, 'Soil Temperature (degree C)')

# %%
g = sns.lmplot(x="Respiration_24_h_ug_CO2.C_per_g_soil_per_day", y="mean_GWC", data=df_env_short,)
g.axes[0,0].set_xlabel('respiration_24hr_CO2 (log ug/g soil/day)')
g.axes[0,0].set_ylabel('Soil Gravimetric Water Content')
# Out:
# Text(36.0, 0.5, 'Soil Gravimetric Water Content')

# %%
sns.pairplot(df_env_short, y_vars=["Respiration_24_h_ug_CO2.C_per_g_soil_per_day"], x_vars=["mean_GWC", "Soil.Temperature.C", "Total_Sulfur_pct"],
             height=5, aspect=1, kind="reg")

# %%
sns.pairplot(df_env_short, y_vars=["Respiration_24_h_ug_CO2.C_per_g_soil_per_day"], x_vars=["Total_Carbon_pct", "Total_Nitrogen_pct", "Mn_mg_per_kg"],
             height=5, aspect=1, kind="reg")

# %%
import seaborn as sns
sns.set_context("paper", rc={'axes.labelsize': 15,'axes.titlesize': 15,'xtick.labelsize': 15,
 'ytick.labelsize': 15,'legend.fontsize': 15, 'legend.title_fontsize': 20,})
ax = sns.pairplot(df_env_short, y_vars=["Respiration_24_h_ug_CO2.C_per_g_soil_per_day"], x_vars=["Mn_mg_per_kg", "Mg_Meq_per_100_g", "Total_Bases_Meq_per_100_g","CEC_Meq_per_100_g"],
             height=5, aspect=1, kind="reg", hue='Depth')
ax.set(ylabel='Respiration_ug_CO2.C_per_g_per_24h')

# %%
ax.savefig('1000s_biogeoc_respir_cor_1.pdf',format='pdf')

# %%
ax=sns.pairplot(df_env_short, y_vars=["Respiration_24_h_ug_CO2.C_per_g_soil_per_day"], x_vars=["Total_Carbon_pct", "Total_Nitrogen_pct", "mean_GWC","Soil.Temperature.C"],
             height=5, aspect=1, kind="reg", hue='Depth')
ax.set(ylabel='Respiration_ug_CO2.C_per_g_per_24h')

# %%
ax.savefig('1000s_biogeoc_respir_cor_2.pdf',format='pdf')

# %%
from scipy import stats
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'Total_Carbon_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'Total_Carbon_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 1.298*x+1.089, R-square: 0.487, p_value: 0.000000
# y = 0.803*x+1.049, R-square: 0.268, p_value: 0.000016

# %%
from scipy import stats
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'SO4.S_mg_per_kg'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'SO4.S_mg_per_kg'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.022*x+1.645, R-square: 0.172, p_value: 0.000716
# y = 0.001*x+1.323, R-square: 0.002, p_value: 0.759330

# %%
 #'NO3.N_mg_per_g_of_soil_mean','NH4.N_mg_per_g_of_soil_mean', 'P_Bicarb_mg_per_g_of_soil_mean',from scipy import stats
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'NH4.N_mg_per_g_of_soil_mean'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'NH4.N_mg_per_g_of_soil_mean'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = -0.094*x+1.853, R-square: 0.002, p_value: 0.760756
# y = -0.003*x+1.364, R-square: 0.000, p_value: 0.991690

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'Total_Nitrogen_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x + {intercept_t:.3f}, R-square : {r_value_t**2:.3f}, p_value : {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'Total_Nitrogen_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x + {intercept_b:.3f}, R-square : {r_value_b**2:.3f}, p_value : {p_value_b:.6f}")
# Out:
# y = 5.277*x + 1.361, R-square : 0.439, p_value : 0.000000
# y = 5.773*x + 1.044, R-square : 0.248, p_value : 0.000039

# %%
from scipy import stats
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'Mn_mg_per_kg'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'Mn_mg_per_kg'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.010*x+1.663, R-square: 0.252, p_value: 0.000027
# y = 0.009*x+1.257, R-square: 0.073, p_value: 0.033652

# %%
df_env_short['Total_Sulfur_pct']= df_env['Total_Sulfur_pct']
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'Total_Sulfur_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'Total_Sulfur_pct'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.001*x+1.693, R-square: 0.080, p_value: 0.028614
# y = 0.001*x+1.270, R-square: 0.036, p_value: 0.160248

# %%
#"Soil.Temperature.C"
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', 'mean_GWC'],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', 'mean_GWC'],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 1.579*x+-0.076, R-square: 0.246, p_value: 0.000041
# y = 1.541*x+-0.442, R-square: 0.225, p_value: 0.000129

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Soil.Temperature.C"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Soil.Temperature.C"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = -0.005*x+2.054, R-square: 0.007, p_value: 0.545038
# y = -0.001*x+1.403, R-square: 0.000, p_value: 0.919342

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "CEC_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "CEC_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.026*x+1.430, R-square: 0.405, p_value: 0.000000
# y = 0.017*x+1.079, R-square: 0.354, p_value: 0.000000

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "CEC_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Total_Carbon_pct']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "CEC_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Total_Carbon_pct']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.014*x+0.359, R-square: 0.428, p_value: 0.000000
# y = 0.008*x+0.228, R-square: 0.209, p_value: 0.000186

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Total_Bases_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Total_Bases_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.021*x+1.646, R-square: 0.146, p_value: 0.001806
# y = 0.018*x+1.171, R-square: 0.227, p_value: 0.000090

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "C_to_N_ratio"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "C_to_N_ratio"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.490*x+1.303, R-square: 0.046, p_value: 0.087340
# y = 0.463*x+0.852, R-square: 0.134, p_value: 0.003458

# %%
df_env_short['C_to_N_ratio']= np.log10(df_env['C_to_N_ratio']+1)
df_env_short['Ca_Meq_per_100_g']= df_env['Ca_Meq_per_100_g']
df_env_short['Mg_Meq_per_100_g']= df_env['Mg_Meq_per_100_g']

#df_env_short['Total_Bases_Meq_per_100_g']= df_env['Total_Bases_Meq_per_100_g']

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Ca_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Ca_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.027*x+1.657, R-square: 0.143, p_value: 0.002037
# y = 0.020*x+1.193, R-square: 0.192, p_value: 0.000372

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Mg_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Mg_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.114*x+1.667, R-square: 0.160, p_value: 0.001044
# y = 0.100*x+1.171, R-square: 0.287, p_value: 0.000007

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "K_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "K_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.000*x+1.840, R-square: 0.004, p_value: 0.637517
# y = 0.000*x+1.252, R-square: 0.053, p_value: 0.070827

# %%
df_env_short['B_mg_per_kg']= df_env['B_mg_per_kg']
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "B_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "B_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.594*x+1.605, R-square: 0.119, p_value: 0.005549
# y = 0.166*x+1.276, R-square: 0.018, p_value: 0.295499

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Zn_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Zn_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.056*x+1.717, R-square: 0.173, p_value: 0.000708
# y = 0.025*x+1.299, R-square: 0.102, p_value: 0.011329

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Fe_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Fe_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.001*x+1.759, R-square: 0.089, p_value: 0.017494
# y = 0.001*x+1.280, R-square: 0.043, p_value: 0.105680

# %%
#Cu_mg_per_kg
#Na_Meq_per_100_g
#pH

df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "pH"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "pH"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = -0.153*x+2.893, R-square: 0.116, p_value: 0.004398
# y = -0.025*x+1.545, R-square: 0.007, p_value: 0.513332

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Na_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Na_Meq_per_100_g"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.048*x+1.860, R-square: 0.005, p_value: 0.577365
# y = 0.150*x+1.313, R-square: 0.026, p_value: 0.210865

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Cu_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Cu_mg_per_kg"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.149*x+1.710, R-square: 0.092, p_value: 0.015561
# y = 0.075*x+1.255, R-square: 0.133, p_value: 0.003631

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Sand_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Sand_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = -0.010*x+2.410, R-square: 0.140, p_value: 0.001403
# y = -0.007*x+1.746, R-square: 0.176, p_value: 0.000368

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Silt_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Silt_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.011*x+1.575, R-square: 0.081, p_value: 0.016863
# y = 0.008*x+1.172, R-square: 0.077, p_value: 0.021925

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Clay_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Clay_pct"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.021*x+1.512, R-square: 0.157, p_value: 0.000692
# y = 0.012*x+1.109, R-square: 0.182, p_value: 0.000289

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Lat"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Lat"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.018*x+1.228, R-square: 0.022, p_value: 0.280906
# y = 0.030*x+0.172, R-square: 0.124, p_value: 0.009697

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Long"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Long"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.000*x+1.991, R-square: 0.000, p_value: 0.911552
# y = -0.001*x+1.296, R-square: 0.002, p_value: 0.756643

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "Elev.m"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "Elev.m"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.000*x+1.778, R-square: 0.136, p_value: 0.005675
# y = 0.000*x+1.295, R-square: 0.090, p_value: 0.029495

# %%
df_t = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='TOP', "VolWaterContent.m3.m3"],
                      'y': df_env_short.loc[df_env_short.depth=='TOP', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_t=df_t.dropna()
slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(df_t.x,df_t.y)
print(f"y = {slope_t:.3f}*x+{intercept_t:.3f}, R-square: {r_value_t**2:.3f}, p_value: {p_value_t:.6f}")

df_b = pd.DataFrame({'x': df_env_short.loc[df_env_short.depth=='BTM', "VolWaterContent.m3.m3"],
                      'y': df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day']})
df_b=df_b.dropna()
slope_b, intercept_b, r_value_b, p_value_b, std_err_b = stats.linregress(df_b.x, df_b.y)
print(f"y = {slope_b:.3f}*x+{intercept_b:.3f}, R-square: {r_value_b**2:.3f}, p_value: {p_value_b:.6f}")
# Out:
# y = 0.926*x+1.753, R-square: 0.061, p_value: 0.069328
# y = 0.919*x+1.194, R-square: 0.112, p_value: 0.014426

# %%
df_env_short['VolWaterContent.m3.m3'].values
# Out:
# array([0.049 , 0.049 , 0.174 , 0.174 , 0.0515, 0.0515, 0.0695, 0.0695,
#        0.338 , 0.338 , 0.047 , 0.261 , 0.261 , 0.28  , 0.28  ,    nan,
#           nan, 0.075 , 0.075 , 0.075 , 0.075 ,    nan,    nan, 0.11  ,
#        0.11  , 0.147 , 0.147 , 0.121 , 0.121 , 0.04  , 0.04  ,    nan,
#           nan, 0.297 , 0.297 , 0.362 , 0.362 ,    nan,    nan, 0.452 ,
#        0.452 ,    nan,    nan,    nan,    nan, 0.093 , 0.093 , 0.3155,
#        0.3155, 0.2645, 0.2645, 0.3055, 0.3055,    nan,    nan, 0.101 ,
#        0.101 , 0.104 , 0.104 , 0.2175, 0.2175, 0.05  , 0.05  , 0.382 ,
#        0.382 , 0.097 , 0.097 , 0.419 , 0.419 , 0.345 , 0.345 , 0.4505,
#        0.4505, 0.177 , 0.177 , 0.194 , 0.194 , 0.045 , 0.045 , 0.23  ,
#        0.23  , 0.466 , 0.466 , 0.027 , 0.027 , 0.042 , 0.042 ,    nan,
#           nan, 0.025 , 0.025 , 0.342 , 0.342 , 0.056 ,    nan,    nan,
#           nan,    nan, 0.32  , 0.32  , 0.335 , 0.335 , 0.198 , 0.198 ,
# ...

# %%
import numpy as np
print(np.where(df_env_short.loc[df_env_short.depth=='TOP', 'Total_Nitrogen_pct'].isna()==True))
print(np.where(df_env_short.loc[df_env_short.depth=='BTM', 'Respiration_24_h_ug_CO2.C_per_g_soil_per_day'].isna()==True))
# Out:
# (array([14, 47, 55, 57, 65, 67]),)
# (array([], dtype=int64),)

# %%
df_env_short.loc[df_env_short.depth=='TOP', 'mean_GWC'].dropna()
# Out:
# Sample
# ANZA_TOP    1.002
# BLAN_TOP    1.157
# CFS1_TOP    1.112
# CFS2_TOP    1.106
# CLBJ_TOP    1.278
#             ...
# WOOD_TOP    1.090
# WREF_TOP    1.221
# WSU1_TOP    1.227
# WSU2_TOP    1.222
# WSU3_TOP    1.424
# Name: mean_GWC, Length: 62, dtype: float64

# %%
df_env_short.loc[df_env_short.depth=='TOP', 'Total_Carbon_pct']
# Out:
# Sample
# ANZA_TOP    0.082426
# BLAN_TOP    0.427486
# CFS1_TOP    0.344785
# CFS2_TOP    0.305136
# CLBJ_TOP    0.406370
#               ...
# WY01_TOP         NaN
# WY03_TOP    1.087142
# WY09_TOP         NaN
# WY10_TOP    0.713323
# WY15_TOP    0.896912
# Name: Total_Carbon_pct, Length: 70, dtype: float64

# %%
#df_env_short['depth'] = [x[5:8] for x in df_env_short.index.values]
boxplot = df_env_short.boxplot(column=['Respiration_24_h_ug_CO2.C_per_g_soil_per_day'],by='depth')

# %%
from scipy.stats import mannwhitneyu
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','Respiration_24_h_ug_CO2.C_per_g_soil_per_day']
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','Respiration_24_h_ug_CO2.C_per_g_soil_per_day']
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 76.75
# 22.0
# 3786.5
# 4.4030608342349336e-10

# %%
df_env_short.boxplot(column=['mean_GWC'],by='depth')
# Out:
# <AxesSubplot:title={'center':'mean_GWC'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','mean_GWC'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','mean_GWC'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 1.174
# 1.1715
# 2052.5
# 0.32796653864533376

# %%
df_env_short.boxplot(column=['pH'],by='depth')
# Out:
# <AxesSubplot:title={'center':'pH'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','pH'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','pH'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 6.46
# 6.545
# 2230.5
# 0.9557860487013065

# %%
df_env_short.boxplot(column=['Total_Nitrogen_pct'],by='depth')
# Out:
# <AxesSubplot:title={'center':'Total_Nitrogen_pct'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','Total_Nitrogen_pct'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','Total_Nitrogen_pct'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 0.202
# 0.10250000000000001
# 3021.0
# 1.8599920850335188e-07

# %%
df_env_short.boxplot(column=['Total_Carbon_pct'],by='depth')
# Out:
# <AxesSubplot:title={'center':'Total_Carbon_pct'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','Total_Carbon_pct'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','Total_Carbon_pct'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 2.8215000000000003
# 1.2325
# 3069.0
# 4.398051486788936e-08

# %%
df_env_short.boxplot(column=['Total_Sulfur_pct'],by='depth')
# Out:
# <AxesSubplot:title={'center':'Total_Sulfur_pct'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','Total_Sulfur_pct'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','Total_Sulfur_pct'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 132.54500000000002
# 84.73
# 2333.0
# 0.0005947754380562507

# %%
df_env_short.boxplot(column=['B.glucosidase_ug_pNP_per_g_per_hour'],by='depth')
# Out:
# <AxesSubplot:title={'center':'B.glucosidase_ug_pNP_per_g_per_hour'}, xlabel='depth'>

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','B.glucosidase_ug_pNP_per_g_per_hour'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','B.glucosidase_ug_pNP_per_g_per_hour'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 70.4
# 15.95
# 3725.5
# 1.155449835345144e-10

# %%
top0 = df_env_short.loc[df_env_short['depth'] =='TOP','Clay_pct'].dropna()
btm0 = df_env_short.loc[df_env_short['depth'] =='BTM','Clay_pct'].dropna()
U1, p = mannwhitneyu(top0, btm0, method="exact")
print(top0.median())
print(btm0.median())
print(U1)
print(p)
# Out:
# 14.76
# 17.979999999999997
# 1993.5
# 0.10075881643967068

# %%
df_env['Respiration_24_h_ug_CO2.C_per_g_soil_per_day'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.feature_selection import SequentialFeatureSelector
df_env_short.columns
# Out:
# Index(['mean_GWC', 'K_mg_per_kg', 'SO4.S_mg_per_kg', 'B_mg_per_kg',
#        'Zn_mg_per_kg', 'Mn_mg_per_kg', 'Cu_mg_per_kg', 'Fe_mg_per_kg',
#        'Ca_Meq_per_100_g', 'Mg_Meq_per_100_g', 'Na_Meq_per_100_g',
#        'Total_Bases_Meq_per_100_g', 'CEC_Meq_per_100_g', 'TKN_pct',
#        'Total_Sulfur_pct', 'Total_Nitrogen_pct', 'Total_Carbon_pct',
#        'C_to_N_ratio', 'NO3.N_mg_per_g_of_soil_mean',
#        'NH4.N_mg_per_g_of_soil_mean', 'P_Bicarb_mg_per_g_of_soil_mean', 'pH',
#        'B.glucosidase_ug_pNP_per_g_per_hour',
#        'Respiration_96_h_ug_CO2.C_per_g_soil_per_day',
#        'Respiration_24_h_ug_CO2.C_per_g_soil_per_day', 'Sand_pct', 'Silt_pct',
#        'Clay_pct', 'Lat', 'Long', 'Elev.m', 'Soil.Temperature.C',
#        'VolWaterContent.m3.m3', 'depth'],
#       dtype='object')

# %%
X = df_env_short.iloc[:,np.append(range(0,23), range(25,33))]
y = df_env_short['Respiration_24_h_ug_CO2.C_per_g_soil_per_day']

# %%
X = X.fillna(X.mean())
X = X.drop(['TKN_pct'], axis=1)

# %%
sfs = SequentialFeatureSelector(linear_model.LinearRegression(),
                                k_features=10,
                                forward=True,
                                scoring='r2',
                                cv=10)

selected_features = sfs.fit(X, y)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
#import matplotlib.pyplot as plt

fig = plot_sfs(sfs.get_metric_dict(), kind='std_err')

plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()

# %%
selected_features.k_feature_names_
# Out:
# ('SO4.S_mg_per_kg',
#  'B_mg_per_kg',
#  'Cu_mg_per_kg',
#  'Mg_Meq_per_100_g',
#  'Total_Nitrogen_pct',
#  'P_Bicarb_mg_per_g_of_soil_mean',
#  'B.glucosidase_ug_pNP_per_g_per_hour',
#  'Silt_pct',
#  'Elev.m',
#  'VolWaterContent.m3.m3')

# %%
sfs = SequentialFeatureSelector(linear_model.LinearRegression(),
                                k_features=7,
                                forward=True,
                                scoring='r2',
                                cv=10)

selected_features = sfs.fit(X, y)

# %%
# Create a dataframe with only the selected features
selected_columns = selected_features.k_feature_names_
df_selected = df_env_short.loc[:,selected_columns]
df_selected = df_selected.fillna(df_selected.mean())
# Split the data into train and test sets
X_train, X_test,\
    y_train, y_test = train_test_split(
        df_selected, y,
        test_size=0.3,
        random_state=20)
  
# Fit a logistic regression model using the selected features
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
  
# Make predictions using the test set
y_pred = lr.predict(X_test)

# %%
plt.plot(y_test, y_pred, 'o')

# %%
y_pred
# Out:
# array([ -4.70259963, 228.58818345, -66.73357715,  88.41471556,
#          1.62481328,  46.9024999 , 156.50834545,  53.88728973,
#         82.52332136, 232.36787829,  55.59140801, -73.52171096,
#        102.46745548, 104.56339766, -74.03124705,  81.64724375,
#         74.55745154,  -9.82069152, 198.77514383,  35.98721833,
#        -60.35958256, 153.99116053,  37.3097292 ,  58.6576586 ,
#        107.15592434,  94.31523773, 131.77371598,  65.02282268,
#         56.84923689,  73.94990369,  52.5072811 , 142.21390935,
#         37.25595111,  -2.82064598,  44.85477032,  68.84152159,
#        159.34738019,  67.88862258,  -7.95411637,  71.80908223,
#         43.01082547,  44.56725901])

# %%
lr.score(X_test, y_test)
# Out:
# 0.12936443985009782

# %%
lr.fit(df_selected, y)
lr.score(df_selected, y)
# Out:
# 0.4617431679746503

# %%
plt.plot(y, lr.predict(df_selected), 'o')
